# %%
#Which of the following description is correct?

#The number of all the words is less than 1,000,000.

#The number of all the words is between 1,000,000 and 2,000,000.

#The number of all the words is between 2,000,000 and 3,000,000.

#The number of all the words is more than 3,000,000. 

amazon_reviews_list = []
file_name = "amazon_reviews.txt"
with open(file_name) as file:
    for line in file:
        amazon_reviews_list.append(line)
        print(line)
#print(amazon_reviews_list

# %%
print(amazon_reviews_list)
