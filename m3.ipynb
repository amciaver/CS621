# %%
l = [23, 11, 34, 56, 23, 11]
l
# Out:
# [23, 11, 34, 56, 23, 11]

# %%
set_l = set(l)
len(set_l)
# Out:
# 4

# %%
set_l
# Out:
# {11, 23, 34, 56}

# %%
import pandas
l = [23, 11, 34, 56, 23, 11]

ser = pandas.Series(l)

# %%
l
# Out:
# [23, 11, 34, 56, 23, 11]

# %%
ser
# Out:
# 0    23
# 1    11
# 2    34
# 3    56
# 4    23
# 5    11
# dtype: int64

# %%
ser[5]
# Out:
# 11

# %%
ser['A']
# Out:
# 34

# %%
values = [23,11,34,56,23,11]
labels = ['A','B','C','D','E','F']
df = pandas.DataFrame({"Name":labels, "Value": values})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 values = [23,11,34,56,23,11]
#       2 labels = ['A','B','C','D','E','F']
# ----> 3 df = pd.DataFrame({"Name":labels, "Value": values})
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
#   Name  Value
# 0    A     23
# 1    B     11
# 2    C     34
# 3    D     56
# 4    E     23
# 5    F     11

# %%
values = [23,11,34,56,23,11]
labels = ['A', 'B', 'C', 'D', 'E', 'F']
df = pandas.DataFrame({"Name":labels, "Value": values})
df
# Out:
#   Name  Value
# 0    A     23
# 1    B     11
# 2    C     34
# 3    D     56
# 4    E     23
# 5    F     11

# %%
df.iloc[3,1]
# Out:
# 56

# %%
df.loc[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df.index
#
# NameError: name 'df' is not defined
