# %%
import pandas as pd
dict = {"Key":["one","two","three"],"Value":[1,2,3]}
df1 = pd.DataFrame(dict)
df1
# Out:
#      Key  Value
# 0    one      1
# 1    two      2
# 2  three      3

# %%
df2=df1.iloc[[1,1]]
df2
# Out:
#    Key  Value
# 1  two      2
# 1  two      2

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df3= df1.iloc[1,1]
df3
# Out:
# 2

# %%
type(df3)
# Out:
# numpy.int64

# %%
import json
with open("iris.json","r") as file:
    
    k = json.load(file)
type(k)
# Out:
# list

# %%
import math
y = math.nan
type(y)
# Out:
# float

# %%
s = ['C','A','B','A']
t = [2,3,2,3]
df4 = pd.DataFrame({"Name":s,"Value":t})
df4
# Out:
#   Name  Value
# 0    C      2
# 1    A      3
# 2    B      2
# 3    A      3

# %%
df5 = df4.drop_duplicates()
df5
# Out:
#   Name  Value
# 0    C      2
# 1    A      3
# 2    B      2

# %%
len(df5)
# Out:
# 3

# %%
I = [35,21,10,55]
ser = pd.Series(I, index = ["D", 'A', 'B', 'C'])
ser
# Out:
# D    35
# A    21
# B    10
# C    55
# dtype: int64

# %%
sorted_ser = ser.sort_index()
sorted_ser
# Out:
# A    21
# B    10
# C    55
# D    35
# dtype: int64

# %%
sorted_ser[0]
# Out:
# /tmp/ipykernel_539/695436071.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sorted_ser[0]
# 21
