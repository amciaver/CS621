# %%
#Which country has the highest alcohol consumption?
# Bekarus
df.loc[df['alcohol'].idxmax(),'location']

# %%
#2What is the smallest alcohol consumption value in dataset alcohol.csv? 
#0.1
df['alcohol'].min()

# %%
#3What is the average alcohol consumption value of all the countries?
# around 6
df['alcohol'].mean()

# %%
#4 
#If we group countries by the first letter of the country names,
#which letter-group has most alcohol consumption in total?
#S
df.groupby(df['location'].str[0])['alcohol'].sum()
